# %%
import pandas as pd
import pydantic
import openai
import os
import anthropic
import instructor
import json
import plotly.graph_objects as go
from __future__ import annotations
import logging 
import typing


from rich.console import Console
console = Console()

# logging.basicConfig(level=logging.DEBUG)

# %%
class dimension(pydantic.BaseModel):
    dimension_name: str
    description: str
    children: list[dimension]

class response(pydantic.BaseModel):
    dimensions: list[dimension]

# %%
class generate_hierarchy:

    # initialize class variables
    def __init__(
            self,
            top_level:str,
            max_iterations,
            client:Literal['openai', 'anthropic'],
            top_levels_separate:bool = False
            ) -> None:
        with open('input_domains/' + str(top_level) + '_domains.json') as f:
            self.input = json.load(f)
        if top_levels_separate:
            with open('prompts/' + str(top_level) + '_separate_prompt.txt') as f:
                self.prompt = f.read()
        else:
            with open('prompts/' + str(top_level) + '_prompt.txt') as f:
                self.prompt = f.read()
        self.max_iterations = max_iterations
        self.top_level = top_level
        self.client = client
        self.top_levels_separate = top_levels_separate
        self.results = []
        self.dimension_names = []
        self.dimension_descriptions = []

    # call api to generate hierarchy
    def api_call(self, prompt, input, domain_name: typing.Optional[str]):
        max_iterations = self.max_iterations
        domain_name = domain_name
        input = input
        # openai gpt-4o
        if self.client == 'openai':
            for i in range(1, self.max_iterations + 1):
                print(i)
                client=instructor.from_openai(openai.OpenAI())
                message = client.chat.completions.create(
                    model='gpt-4o',
                    response_model=response,
                    messages=[
                        {'role':'user',
                        'content':eval(prompt)},
                    ]
                )
                iterations_completed = i
                current_model = [x.model_dump() for x in message.dimensions]
                if input == current_model:
                    print('finished on iteration ', i-1)
                    break
                if iterations_completed == self.max_iterations:
                    print('completed all ', self.max_iterations, ' iterations')
                input = current_model
        # anthropic claude 3.5 sonnet
        if self.client == 'anthropic':
            region = 'us-west-2'
            for i in range(1, self.max_iterations + 1):
                print(i)
                client = instructor.from_anthropic(anthropic.AnthropicBedrock(
                    aws_access_key = os.environ.get('AWS_ACCESS_KEY_ID'),
                    aws_secret_key = os.environ.get('AWS_SECRET_ACCESS_KEY'),
                    aws_region=region,
                ))

                message = client.messages.create(
                    model='anthropic.claude-3-5-sonnet-20241022-v2:0',
                    response_model=response,
                    max_tokens=80000,
                    messages=[
                        {'role':'user',
                        'content':eval(prompt)},
                        ],
                    )
                iterations_completed = i 
                current_model = [x.model_dump() for x in message.dimensions]
                print(current_model)
                if input == current_model:
                    print('finished on iteration ', i)
                    break
                if iterations_completed == self.max_iterations:
                    print('completed all ', self.max_iterations, ' iterations')
                input = current_model

        return current_model, iterations_completed

    # parse model to format as table
    def parse_node(self, node, hierarchy):
        if len(node['children']) == 0:
            self.results.append(hierarchy + [node['dimension_name']])
            if node['dimension_name'] not in self.dimension_names:
                self.dimension_names.append(node['dimension_name'])
            if node['description'] not in self.dimension_descriptions:
                self.dimension_descriptions.append(node['description'])   
        else:
            self.results.append(hierarchy + [node['dimension_name']])
            for child in node['children']:
                child_hierarchy = hierarchy.copy()
                child_hierarchy.append(node['dimension_name'])
                if node['dimension_name'] not in self.dimension_names:
                    self.dimension_names.append(node['dimension_name'])
                if node['description'] not in self.dimension_descriptions:
                    self.dimension_descriptions.append(node['description']) 
                self.parse_node(child, child_hierarchy)

    # generate and save the hierarchy 
    def run(self):
        if self.top_levels_separate:
            model = []
            iterations_completed = 0
            for domain in self.input:
                domain_name = domain['dimension_name']
                domain_model, domain_iterations_completed = self.api_call(self.prompt, domain, domain_name)
                model.append(domain_model[0])
                if domain_iterations_completed > iterations_completed:
                    iterations_completed = domain_iterations_completed
        else:
            model, iterations_completed = self.api_call(self.prompt,self.input)
        for domain in model:
            self.parse_node(domain, []) 
        description_dict = dict(zip(self.dimension_names, self.dimension_descriptions))
        for row in self.results:
            print(row)
            dimension = row[-1]
            print(dimension)
            description = description_dict[dimension]
            if len(row) < (iterations_completed + 1):
                row.extend([pd.NA] * ((iterations_completed + 1) - len(row)))
            row.append(description)
        print(row)
        result_df = pd.DataFrame(self.results)
        result_df.columns = [f'level_{i}' for i in range(1, len(result_df.columns))] + ['description']
        # save model as json and csv
        with open('results/' + str(self.top_level) + '_hierarchy.json', 'w') as f:
            json.dump(model, f)
        result_df = result_df.dropna(how='all', axis=1).fillna('')
        result_df.to_csv('results/' + str(self.top_level) + '_' + str(self.client) + '_hierarchy.csv', index=False)
        return model, result_df

# %%
model, result_df = generate_hierarchy(top_level='generated', max_iterations=5, client = 'anthropic', top_levels_separate=True).run()
# Out:
# 1
# [{'dimension_name': 'Cognitive Function', 'description': 'The mental processes involved in acquiring, processing, and utilizing information, including thinking, reasoning, learning, and memory.', 'children': [{'dimension_name': 'Memory', 'description': 'The ability to encode, store, retain, and recall information and experiences.', 'children': []}, {'dimension_name': 'Executive Function', 'description': 'Higher-order cognitive processes that enable goal-directed behavior, including planning, decision-making, and mental flexibility.', 'children': []}, {'dimension_name': 'Processing Speed', 'description': 'The efficiency and speed with which cognitive tasks are performed and information is processed.', 'children': []}, {'dimension_name': 'Language Processing', 'description': 'The cognitive aspects of understanding and using language, including comprehension and production.', 'children': []}, {'dimension_name': 'Visual-Spatial Processing', 'description': 'The ability to perceive, analyze, synthesize, and manipulate visual-spatial information.', 'children': []}, {'dimension_name': 'Learning', 'description': 'The cognitive processes involved in acquiring new knowledge and skills through experience and instruction.', 'children': []}, {'dimension_name': 'Reasoning', 'description': 'The ability to think logically, solve problems, and draw conclusions from information.', 'children': []}]}]
# 2
# [{'dimension_name': 'Cognitive Function', 'description': 'The mental processes involved in acquiring, processing, and utilizing information, including thinking, reasoning, learning, and memory.', 'children': [{'dimension_name': 'Memory', 'description': 'The ability to encode, store, retain, and recall information and experiences.', 'children': [{'dimension_name': 'Working Memory', 'description': 'The ability to temporarily hold and manipulate information for cognitive tasks.', 'children': []}, {'dimension_name': 'Long-term Memory', 'description': 'The storage and retrieval of information over extended periods of time.', 'children': []}, {'dimension_name': 'Short-term Memory', 'description': 'The capacity to hold a small amount of information in a readily available state for a brief period.', 'children': []}]}, {'dimension_name': 'Executive Function', 'description': 'Higher-order cognitive processes that enable goal-directed behavior, including planning, decision-making, and mental flexibility.', 'children': [{'dimension_name': 'Cognitive Flexibility', 'description': 'The ability to adapt thinking and behavior in response to changing situations or requirements.', 'children': []}, {'dimension_name': 'Inhibitory Control', 'description': 'The ability to suppress inappropriate responses and resist interference from irrelevant information.', 'children': []}, {'dimension_name': 'Planning and Organization', 'description': 'The ability to develop strategies, organize information, and plan steps to achieve goals.', 'children': []}]}, {'dimension_name': 'Processing Speed', 'description': 'The efficiency and speed with which cognitive tasks are performed and information is processed.', 'children': []}, {'dimension_name': 'Language Processing', 'description': 'The cognitive aspects of understanding and using language, including comprehension and production.', 'children': [{'dimension_name': 'Verbal Comprehension', 'description': 'The ability to understand and process spoken or written language.', 'children': []}, {'dimension_name': 'Verbal Expression', 'description': 'The ability to produce and articulate language to communicate thoughts and ideas.', 'children': []}]}, {'dimension_name': 'Visual-Spatial Processing', 'description': 'The ability to perceive, analyze, synthesize, and manipulate visual-spatial information.', 'children': [{'dimension_name': 'Visual Processing', 'description': 'The ability to perceive, analyze, and interpret visual information.', 'children': []}, {'dimension_name': 'Spatial Processing', 'description': 'The ability to understand and manipulate spatial relationships and mental representations.', 'children': []}]}, {'dimension_name': 'Learning', 'description': 'The cognitive processes involved in acquiring new knowledge and skills through experience and instruction.', 'children': [{'dimension_name': 'Skill Acquisition', 'description': 'The process of learning and mastering new abilities and procedures.', 'children': []}, {'dimension_name': 'Knowledge Acquisition', 'description': 'The process of learning and incorporating new information and concepts.', 'children': []}]}, {'dimension_name': 'Reasoning', 'description': 'The ability to think logically, solve problems, and draw conclusions from information.', 'children': [{'dimension_name': 'Abstract Reasoning', 'description': 'The ability to understand and manipulate abstract concepts and patterns.', 'children': []}, {'dimension_name': 'Problem Solving', 'description': 'The ability to identify problems and generate effective solutions.', 'children': []}]}]}]
# 3
# [{'dimension_name': 'Cognitive Function', 'description': 'The mental processes involved in acquiring, processing, and utilizing information, including thinking, reasoning, learning, and memory.', 'children': [{'dimension_name': 'Memory', 'description': 'The ability to encode, store, retain, and recall information and experiences.', 'children': [{'dimension_name': 'Working Memory', 'description': 'The ability to temporarily hold and manipulate information for cognitive tasks.', 'children': [{'dimension_name': 'Verbal Working Memory', 'description': 'The ability to temporarily store and manipulate verbal information.', 'children': []}, {'dimension_name': 'Visual-Spatial Working Memory', 'description': 'The ability to temporarily store and manipulate visual and spatial information.', 'children': []}]}, {'dimension_name': 'Long-term Memory', 'description': 'The storage and retrieval of information over extended periods of time.', 'children': [{'dimension_name': 'Declarative Memory', 'description': 'Conscious recollection of facts and events, including both episodic and semantic memory.', 'children': []}, {'dimension_name': 'Procedural Memory', 'description': 'Memory for skills, procedures, and habits that are typically performed automatically.', 'children': []}]}, {'dimension_name': 'Short-term Memory', 'description': 'The capacity to hold a small amount of information in a readily available state for a brief period.', 'children': [{'dimension_name': 'Auditory Short-term Memory', 'description': 'The ability to temporarily retain auditory information.', 'children': []}, {'dimension_name': 'Visual Short-term Memory', 'description': 'The ability to temporarily retain visual information.', 'children': []}]}]}, {'dimension_name': 'Executive Function', 'description': 'Higher-order cognitive processes that enable goal-directed behavior, including planning, decision-making, and mental flexibility.', 'children': [{'dimension_name': 'Cognitive Flexibility', 'description': 'The ability to adapt thinking and behavior in response to changing situations or requirements.', 'children': [{'dimension_name': 'Task Switching', 'description': 'The ability to shift attention between different tasks or mental sets.', 'children': []}, {'dimension_name': 'Adaptive Thinking', 'description': 'The ability to modify strategies and approaches based on feedback or changing conditions.', 'children': []}]}, {'dimension_name': 'Inhibitory Control', 'description': 'The ability to suppress inappropriate responses and resist interference from irrelevant information.', 'children': [{'dimension_name': 'Response Inhibition', 'description': 'The ability to suppress automatic or prepotent responses.', 'children': []}, {'dimension_name': 'Interference Control', 'description': 'The ability to filter out irrelevant information and maintain focus on relevant information.', 'children': []}]}, {'dimension_name': 'Planning and Organization', 'description': 'The ability to develop strategies, organize information, and plan steps to achieve goals.', 'children': [{'dimension_name': 'Strategic Planning', 'description': 'The ability to formulate and sequence steps to achieve specific goals.', 'children': []}, {'dimension_name': 'Time Management', 'description': 'The ability to organize and prioritize tasks within time constraints.', 'children': []}]}]}, {'dimension_name': 'Processing Speed', 'description': 'The efficiency and speed with which cognitive tasks are performed and information is processed.', 'children': [{'dimension_name': 'Perceptual Processing Speed', 'description': 'The speed at which visual or auditory information is processed and understood.', 'children': []}, {'dimension_name': 'Cognitive Processing Speed', 'description': 'The speed at which mental operations and problem-solving tasks are completed.', 'children': []}]}, {'dimension_name': 'Language Processing', 'description': 'The cognitive aspects of understanding and using language, including comprehension and pro ...
# 4
# [{'dimension_name': 'Cognitive Function', 'description': 'The mental processes involved in acquiring, processing, and utilizing information, including thinking, reasoning, learning, and memory.', 'children': [{'dimension_name': 'Memory', 'description': 'The ability to encode, store, retain, and recall information and experiences.', 'children': [{'dimension_name': 'Working Memory', 'description': 'The ability to temporarily hold and manipulate information for cognitive tasks.', 'children': [{'dimension_name': 'Verbal Working Memory', 'description': 'The ability to temporarily store and manipulate verbal information.', 'children': [{'dimension_name': 'Phonological Loop', 'description': 'The system for temporarily storing and rehearsing speech-based information.', 'children': []}, {'dimension_name': 'Semantic Working Memory', 'description': 'The ability to temporarily maintain and manipulate meaning-based verbal information.', 'children': []}]}, {'dimension_name': 'Visual-Spatial Working Memory', 'description': 'The ability to temporarily store and manipulate visual and spatial information.', 'children': [{'dimension_name': 'Visual Buffer', 'description': 'The system for temporarily maintaining visual information in working memory.', 'children': []}, {'dimension_name': 'Spatial Manipulation', 'description': 'The ability to mentally manipulate spatial information in working memory.', 'children': []}]}]}, {'dimension_name': 'Long-term Memory', 'description': 'The storage and retrieval of information over extended periods of time.', 'children': [{'dimension_name': 'Declarative Memory', 'description': 'Conscious recollection of facts and events, including both episodic and semantic memory.', 'children': [{'dimension_name': 'Episodic Memory', 'description': 'Memory for personally experienced events and their temporal-spatial context.', 'children': []}, {'dimension_name': 'Semantic Memory', 'description': 'Memory for general knowledge, concepts, and facts about the world.', 'children': []}]}, {'dimension_name': 'Procedural Memory', 'description': 'Memory for skills, procedures, and habits that are typically performed automatically.', 'children': [{'dimension_name': 'Motor Procedural Memory', 'description': 'Memory for physical motor skills and sequences.', 'children': []}, {'dimension_name': 'Cognitive Procedural Memory', 'description': 'Memory for cognitive routines and problem-solving procedures.', 'children': []}]}]}, {'dimension_name': 'Short-term Memory', 'description': 'The capacity to hold a small amount of information in a readily available state for a brief period.', 'children': [{'dimension_name': 'Auditory Short-term Memory', 'description': 'The ability to temporarily retain auditory information.', 'children': []}, {'dimension_name': 'Visual Short-term Memory', 'description': 'The ability to temporarily retain visual information.', 'children': []}]}]}, {'dimension_name': 'Executive Function', 'description': 'Higher-order cognitive processes that enable goal-directed behavior, including planning, decision-making, and mental flexibility.', 'children': [{'dimension_name': 'Cognitive Flexibility', 'description': 'The ability to adapt thinking and behavior in response to changing situations or requirements.', 'children': [{'dimension_name': 'Task Switching', 'description': 'The ability to shift attention between different tasks or mental sets.', 'children': []}, {'dimension_name': 'Adaptive Thinking', 'description': 'The ability to modify strategies and approaches based on feedback or changing conditions.', 'children': []}]}, {'dimension_name': 'Inhibitory Control', 'description': 'The ability to suppress inappropriate responses and resist interference from irrelevant information.', 'children': [{'dimension_name': 'Response Inhibition', 'description': 'The ability to suppress automatic or prepotent responses.', 'children': []}, {'dimension_name': 'Interference Control', 'description': 'The ability to filter out irrelevant informa ...
# 5
# [{'dimension_name': 'Cognitive Function', 'description': 'The mental processes involved in acquiring, processing, and utilizing information, including thinking, reasoning, learning, and memory.', 'children': [{'dimension_name': 'Memory', 'description': 'The ability to encode, store, retain, and recall information and experiences.', 'children': [{'dimension_name': 'Working Memory', 'description': 'The ability to temporarily hold and manipulate information for cognitive tasks.', 'children': [{'dimension_name': 'Verbal Working Memory', 'description': 'The ability to temporarily store and manipulate verbal information.', 'children': [{'dimension_name': 'Phonological Loop', 'description': 'The system for temporarily storing and rehearsing speech-based information.', 'children': []}, {'dimension_name': 'Semantic Working Memory', 'description': 'The ability to temporarily maintain and manipulate meaning-based verbal information.', 'children': []}]}, {'dimension_name': 'Visual-Spatial Working Memory', 'description': 'The ability to temporarily store and manipulate visual and spatial information.', 'children': [{'dimension_name': 'Visual Buffer', 'description': 'The system for temporarily maintaining visual information in working memory.', 'children': []}, {'dimension_name': 'Spatial Manipulation', 'description': 'The ability to mentally manipulate spatial information in working memory.', 'children': []}]}]}, {'dimension_name': 'Long-term Memory', 'description': 'The storage and retrieval of information over extended periods of time.', 'children': [{'dimension_name': 'Declarative Memory', 'description': 'Conscious recollection of facts and events, including both episodic and semantic memory.', 'children': [{'dimension_name': 'Episodic Memory', 'description': 'Memory for personally experienced events and their temporal-spatial context.', 'children': []}, {'dimension_name': 'Semantic Memory', 'description': 'Memory for general knowledge, concepts, and facts about the world.', 'children': []}]}, {'dimension_name': 'Procedural Memory', 'description': 'Memory for skills, procedures, and habits that are typically performed automatically.', 'children': [{'dimension_name': 'Motor Procedural Memory', 'description': 'Memory for physical motor skills and sequences.', 'children': []}, {'dimension_name': 'Cognitive Procedural Memory', 'description': 'Memory for cognitive routines and problem-solving procedures.', 'children': []}]}]}, {'dimension_name': 'Short-term Memory', 'description': 'The capacity to hold a small amount of information in a readily available state for a brief period.', 'children': [{'dimension_name': 'Auditory Short-term Memory', 'description': 'The ability to temporarily retain auditory information.', 'children': []}, {'dimension_name': 'Visual Short-term Memory', 'description': 'The ability to temporarily retain visual information.', 'children': []}]}]}, {'dimension_name': 'Executive Function', 'description': 'Higher-order cognitive processes that enable goal-directed behavior, including planning, decision-making, and mental flexibility.', 'children': [{'dimension_name': 'Cognitive Flexibility', 'description': 'The ability to adapt thinking and behavior in response to changing situations or requirements.', 'children': [{'dimension_name': 'Task Switching', 'description': 'The ability to shift attention between different tasks or mental sets.', 'children': []}, {'dimension_name': 'Adaptive Thinking', 'description': 'The ability to modify strategies and approaches based on feedback or changing conditions.', 'children': []}]}, {'dimension_name': 'Inhibitory Control', 'description': 'The ability to suppress inappropriate responses and resist interference from irrelevant information.', 'children': [{'dimension_name': 'Response Inhibition', 'description': 'The ability to suppress automatic or prepotent responses.', 'children': []}, {'dimension_name': 'Interference Control', 'description': 'The ability to filter out irrelevant informa ...
# finished on iteration  5
# 1
# [{'dimension_name': 'Emotion Regulation', 'description': 'The ability to recognize, understand, and manage emotional responses in an adaptive and contextually appropriate manner', 'children': [{'dimension_name': 'Emotional Awareness', 'description': 'The ability to recognize and identify emotions in oneself and others', 'children': []}, {'dimension_name': 'Emotional Expression', 'description': 'The ability to express emotions appropriately and effectively in different contexts', 'children': []}, {'dimension_name': 'Emotional Control', 'description': 'The ability to modulate and manage emotional responses in accordance with situational demands', 'children': []}, {'dimension_name': 'Emotional Recovery', 'description': 'The ability to return to a balanced emotional state after experiencing intense emotions', 'children': []}, {'dimension_name': 'Emotional Flexibility', 'description': 'The ability to adapt emotional responses to changing circumstances and shift between different emotional states', 'children': []}]}]
# 2
# [{'dimension_name': 'Emotion Regulation', 'description': 'The ability to recognize, understand, and manage emotional responses in an adaptive and contextually appropriate manner', 'children': [{'dimension_name': 'Emotional Awareness', 'description': 'The ability to recognize and identify emotions in oneself and others', 'children': [{'dimension_name': 'Self-Emotional Awareness', 'description': "The ability to identify and understand one's own emotional states and their triggers", 'children': []}, {'dimension_name': 'Social-Emotional Awareness', 'description': "The ability to recognize and understand others' emotional states and their social implications", 'children': []}]}, {'dimension_name': 'Emotional Expression', 'description': 'The ability to express emotions appropriately and effectively in different contexts', 'children': [{'dimension_name': 'Verbal Expression', 'description': 'The ability to communicate emotions through words and language', 'children': []}, {'dimension_name': 'Non-verbal Expression', 'description': 'The ability to convey emotions through facial expressions, body language, and tone of voice', 'children': []}, {'dimension_name': 'Expression Appropriateness', 'description': 'The ability to adjust emotional expression according to social context and cultural norms', 'children': []}]}, {'dimension_name': 'Emotional Control', 'description': 'The ability to modulate and manage emotional responses in accordance with situational demands', 'children': [{'dimension_name': 'Response Inhibition', 'description': 'The ability to suppress or moderate immediate emotional reactions when necessary', 'children': []}, {'dimension_name': 'Emotional Modulation', 'description': 'The ability to adjust the intensity and duration of emotional responses', 'children': []}]}, {'dimension_name': 'Emotional Recovery', 'description': 'The ability to return to a balanced emotional state after experiencing intense emotions', 'children': [{'dimension_name': 'Self-Soothing', 'description': 'The ability to use internal strategies to calm oneself and reduce emotional intensity', 'children': []}, {'dimension_name': 'Support Seeking', 'description': 'The ability to identify when and how to seek external support for emotional regulation', 'children': []}]}, {'dimension_name': 'Emotional Flexibility', 'description': 'The ability to adapt emotional responses to changing circumstances and shift between different emotional states', 'children': [{'dimension_name': 'Cognitive Reappraisal', 'description': 'The ability to reframe situations and adjust emotional responses based on new perspectives', 'children': []}, {'dimension_name': 'Emotional Transitions', 'description': 'The ability to move between different emotional states smoothly and appropriately', 'children': []}]}]}]
# 3
# [{'dimension_name': 'Emotion Regulation', 'description': 'The ability to recognize, understand, and manage emotional responses in an adaptive and contextually appropriate manner', 'children': [{'dimension_name': 'Emotional Awareness', 'description': 'The ability to recognize and identify emotions in oneself and others', 'children': [{'dimension_name': 'Self-Emotional Awareness', 'description': "The ability to identify and understand one's own emotional states and their triggers", 'children': [{'dimension_name': 'Emotional Recognition', 'description': 'The ability to accurately identify specific emotions as they occur in oneself', 'children': []}, {'dimension_name': 'Trigger Identification', 'description': 'The ability to recognize and understand specific events, thoughts, or situations that prompt emotional responses', 'children': []}]}, {'dimension_name': 'Social-Emotional Awareness', 'description': "The ability to recognize and understand others' emotional states and their social implications", 'children': [{'dimension_name': 'Empathetic Recognition', 'description': 'The ability to accurately identify and understand emotions in others through their expressions and behaviors', 'children': []}, {'dimension_name': 'Contextual Understanding', 'description': 'The ability to understand how social context and relationships influence emotional expressions and responses in others', 'children': []}]}]}, {'dimension_name': 'Emotional Expression', 'description': 'The ability to express emotions appropriately and effectively in different contexts', 'children': [{'dimension_name': 'Verbal Expression', 'description': 'The ability to communicate emotions through words and language', 'children': [{'dimension_name': 'Emotional Vocabulary', 'description': 'The ability to use precise and varied language to describe emotional experiences', 'children': []}, {'dimension_name': 'Narrative Expression', 'description': 'The ability to communicate about emotional experiences in a coherent and meaningful way', 'children': []}]}, {'dimension_name': 'Non-verbal Expression', 'description': 'The ability to convey emotions through facial expressions, body language, and tone of voice', 'children': [{'dimension_name': 'Facial Expressiveness', 'description': 'The ability to convey emotions through appropriate facial expressions', 'children': []}, {'dimension_name': 'Body Language Control', 'description': 'The ability to use appropriate posture and gestures to convey emotional states', 'children': []}, {'dimension_name': 'Vocal Expression', 'description': 'The ability to modulate voice tone and pitch to convey emotional meaning', 'children': []}]}, {'dimension_name': 'Expression Appropriateness', 'description': 'The ability to adjust emotional expression according to social context and cultural norms', 'children': [{'dimension_name': 'Cultural Awareness', 'description': 'The ability to understand and adapt emotional expressions to cultural expectations and norms', 'children': []}, {'dimension_name': 'Situational Adjustment', 'description': 'The ability to modify emotional expressions based on specific social contexts and settings', 'children': []}]}]}, {'dimension_name': 'Emotional Control', 'description': 'The ability to modulate and manage emotional responses in accordance with situational demands', 'children': [{'dimension_name': 'Response Inhibition', 'description': 'The ability to suppress or moderate immediate emotional reactions when necessary', 'children': [{'dimension_name': 'Impulse Control', 'description': 'The ability to resist immediate emotional urges and reactions', 'children': []}, {'dimension_name': 'Response Delay', 'description': 'The ability to pause and consider consequences before acting on emotional impulses', 'children': []}]}, {'dimension_name': 'Emotional Modulation', 'description': 'The ability to adjust the intensity and duration of emotional responses', 'children': [{'dimension_name': 'Intensity Management', 'description': 'The abili ...
# 4
# [{'dimension_name': 'Emotion Regulation', 'description': 'The ability to recognize, understand, and manage emotional responses in an adaptive and contextually appropriate manner', 'children': [{'dimension_name': 'Emotional Awareness', 'description': 'The ability to recognize and identify emotions in oneself and others', 'children': [{'dimension_name': 'Self-Emotional Awareness', 'description': "The ability to identify and understand one's own emotional states and their triggers", 'children': [{'dimension_name': 'Emotional Recognition', 'description': 'The ability to accurately identify specific emotions as they occur in oneself', 'children': [{'dimension_name': 'Primary Emotion Recognition', 'description': 'The ability to identify basic emotions such as happiness, sadness, anger, fear', 'children': []}, {'dimension_name': 'Complex Emotion Recognition', 'description': 'The ability to identify and differentiate more nuanced emotional states such as disappointment, pride, guilt', 'children': []}]}, {'dimension_name': 'Trigger Identification', 'description': 'The ability to recognize and understand specific events, thoughts, or situations that prompt emotional responses', 'children': [{'dimension_name': 'External Trigger Recognition', 'description': 'The ability to identify environmental or situational factors that trigger emotional responses', 'children': []}, {'dimension_name': 'Internal Trigger Recognition', 'description': 'The ability to identify thoughts, memories, or physiological states that trigger emotional responses', 'children': []}]}]}, {'dimension_name': 'Social-Emotional Awareness', 'description': "The ability to recognize and understand others' emotional states and their social implications", 'children': [{'dimension_name': 'Empathetic Recognition', 'description': 'The ability to accurately identify and understand emotions in others through their expressions and behaviors', 'children': [{'dimension_name': 'Verbal Cue Recognition', 'description': "The ability to identify emotions through others' spoken words and tone", 'children': []}, {'dimension_name': 'Non-verbal Cue Recognition', 'description': "The ability to identify emotions through others' facial expressions, gestures, and body language", 'children': []}]}, {'dimension_name': 'Contextual Understanding', 'description': 'The ability to understand how social context and relationships influence emotional expressions and responses in others', 'children': [{'dimension_name': 'Relationship Context', 'description': 'The ability to understand how different relationship dynamics affect emotional expressions', 'children': []}, {'dimension_name': 'Environmental Context', 'description': 'The ability to understand how different settings and situations influence emotional expressions', 'children': []}]}]}]}, {'dimension_name': 'Emotional Expression', 'description': 'The ability to express emotions appropriately and effectively in different contexts', 'children': [{'dimension_name': 'Verbal Expression', 'description': 'The ability to communicate emotions through words and language', 'children': [{'dimension_name': 'Emotional Vocabulary', 'description': 'The ability to use precise and varied language to describe emotional experiences', 'children': [{'dimension_name': 'Basic Emotion Vocabulary', 'description': 'The ability to use words for fundamental emotions and feelings', 'children': []}, {'dimension_name': 'Complex Emotion Vocabulary', 'description': 'The ability to use sophisticated language for nuanced emotional experiences', 'children': []}]}, {'dimension_name': 'Narrative Expression', 'description': 'The ability to communicate about emotional experiences in a coherent and meaningful way', 'children': [{'dimension_name': 'Sequential Description', 'description': 'The ability to describe emotional experiences in a logical, time-ordered manner', 'children': []}, {'dimension_name': 'Contextual Description', 'description': 'The ability to explain the circumstances and factor ...
# 5
# [{'dimension_name': 'Emotion Regulation', 'description': 'The ability to recognize, understand, and manage emotional responses in an adaptive and contextually appropriate manner', 'children': [{'dimension_name': 'Emotional Awareness', 'description': 'The ability to recognize and identify emotions in oneself and others', 'children': [{'dimension_name': 'Self-Emotional Awareness', 'description': "The ability to identify and understand one's own emotional states and their triggers", 'children': [{'dimension_name': 'Emotional Recognition', 'description': 'The ability to accurately identify specific emotions as they occur in oneself', 'children': [{'dimension_name': 'Primary Emotion Recognition', 'description': 'The ability to identify basic emotions such as happiness, sadness, anger, fear', 'children': []}, {'dimension_name': 'Complex Emotion Recognition', 'description': 'The ability to identify and differentiate more nuanced emotional states such as disappointment, pride, guilt', 'children': []}]}, {'dimension_name': 'Trigger Identification', 'description': 'The ability to recognize and understand specific events, thoughts, or situations that prompt emotional responses', 'children': [{'dimension_name': 'External Trigger Recognition', 'description': 'The ability to identify environmental or situational factors that trigger emotional responses', 'children': []}, {'dimension_name': 'Internal Trigger Recognition', 'description': 'The ability to identify thoughts, memories, or physiological states that trigger emotional responses', 'children': []}]}]}, {'dimension_name': 'Social-Emotional Awareness', 'description': "The ability to recognize and understand others' emotional states and their social implications", 'children': [{'dimension_name': 'Empathetic Recognition', 'description': 'The ability to accurately identify and understand emotions in others through their expressions and behaviors', 'children': [{'dimension_name': 'Verbal Cue Recognition', 'description': "The ability to identify emotions through others' spoken words and tone", 'children': []}, {'dimension_name': 'Non-verbal Cue Recognition', 'description': "The ability to identify emotions through others' facial expressions, gestures, and body language", 'children': []}]}, {'dimension_name': 'Contextual Understanding', 'description': 'The ability to understand how social context and relationships influence emotional expressions and responses in others', 'children': [{'dimension_name': 'Relationship Context', 'description': 'The ability to understand how different relationship dynamics affect emotional expressions', 'children': []}, {'dimension_name': 'Environmental Context', 'description': 'The ability to understand how different settings and situations influence emotional expressions', 'children': []}]}]}]}, {'dimension_name': 'Emotional Expression', 'description': 'The ability to express emotions appropriately and effectively in different contexts', 'children': [{'dimension_name': 'Verbal Expression', 'description': 'The ability to communicate emotions through words and language', 'children': [{'dimension_name': 'Emotional Vocabulary', 'description': 'The ability to use precise and varied language to describe emotional experiences', 'children': [{'dimension_name': 'Basic Emotion Vocabulary', 'description': 'The ability to use words for fundamental emotions and feelings', 'children': []}, {'dimension_name': 'Complex Emotion Vocabulary', 'description': 'The ability to use sophisticated language for nuanced emotional experiences', 'children': []}]}, {'dimension_name': 'Narrative Expression', 'description': 'The ability to communicate about emotional experiences in a coherent and meaningful way', 'children': [{'dimension_name': 'Sequential Description', 'description': 'The ability to describe emotional experiences in a logical, time-ordered manner', 'children': []}, {'dimension_name': 'Contextual Description', 'description': 'The ability to explain the circumstances and factor ...
# finished on iteration  5
# 1
# [{'dimension_name': 'Social Interaction', 'description': 'The ability to engage, respond to, and maintain relationships with others, encompassing both verbal and non-verbal aspects of social behavior and understanding', 'children': [{'dimension_name': 'Social Communication', 'description': 'The ability to send and receive social messages through verbal and non-verbal means, including facial expressions, body language, and tone of voice', 'children': []}, {'dimension_name': 'Social Understanding', 'description': "The ability to interpret and comprehend social situations, including understanding others' emotions, intentions, and social norms", 'children': []}, {'dimension_name': 'Social Relationships', 'description': 'The ability to form and maintain relationships with others, including peers, family members, and authority figures', 'children': []}, {'dimension_name': 'Social Initiative', 'description': 'The tendency to initiate and engage in social interactions, including approaching others and joining group activities', 'children': []}]}]
# 2
# [{'dimension_name': 'Social Interaction', 'description': 'The ability to engage, respond to, and maintain relationships with others, encompassing both verbal and non-verbal aspects of social behavior and understanding', 'children': [{'dimension_name': 'Social Communication', 'description': 'The ability to send and receive social messages through verbal and non-verbal means, including facial expressions, body language, and tone of voice', 'children': [{'dimension_name': 'Verbal Social Communication', 'description': 'The ability to use and understand spoken language in social contexts, including conversation skills and appropriate verbal responses', 'children': []}, {'dimension_name': 'Non-verbal Social Communication', 'description': 'The ability to use and understand non-verbal cues such as facial expressions, gestures, body language, and spatial awareness in social interactions', 'children': []}]}, {'dimension_name': 'Social Understanding', 'description': "The ability to interpret and comprehend social situations, including understanding others' emotions, intentions, and social norms", 'children': [{'dimension_name': 'Emotional Recognition', 'description': 'The ability to identify and understand emotions in others through facial expressions, vocal tones, and body language', 'children': []}, {'dimension_name': 'Social Context Understanding', 'description': 'The ability to understand and navigate different social situations, including awareness of social norms and appropriate behavior in various contexts', 'children': []}, {'dimension_name': 'Perspective Taking', 'description': "The ability to understand and consider others' thoughts, feelings, and viewpoints, including theory of mind", 'children': []}]}, {'dimension_name': 'Social Relationships', 'description': 'The ability to form and maintain relationships with others, including peers, family members, and authority figures', 'children': [{'dimension_name': 'Peer Relationships', 'description': 'The ability to form and maintain age-appropriate relationships with peers, including friendships and group interactions', 'children': []}, {'dimension_name': 'Family Relationships', 'description': 'The ability to maintain appropriate relationships with family members, including understanding and respecting family roles and boundaries', 'children': []}, {'dimension_name': 'Authority Relationships', 'description': 'The ability to interact appropriately with authority figures, including understanding hierarchical relationships and showing appropriate respect', 'children': []}]}, {'dimension_name': 'Social Initiative', 'description': 'The tendency to initiate and engage in social interactions, including approaching others and joining group activities', 'children': [{'dimension_name': 'Social Approach', 'description': 'The tendency to initiate contact and engage with others in social situations', 'children': []}, {'dimension_name': 'Group Participation', 'description': 'The ability to join and actively participate in group activities and social situations', 'children': []}]}]}]
# 3
# [{'dimension_name': 'Social Interaction', 'description': 'The ability to engage, respond to, and maintain relationships with others, encompassing both verbal and non-verbal aspects of social behavior and understanding', 'children': [{'dimension_name': 'Social Communication', 'description': 'The ability to send and receive social messages through verbal and non-verbal means, including facial expressions, body language, and tone of voice', 'children': [{'dimension_name': 'Verbal Social Communication', 'description': 'The ability to use and understand spoken language in social contexts, including conversation skills and appropriate verbal responses', 'children': [{'dimension_name': 'Conversational Flow', 'description': 'The ability to maintain back-and-forth dialogue, including turn-taking and topic maintenance in conversations', 'children': []}, {'dimension_name': 'Social Language Use', 'description': 'The ability to use appropriate language for different social situations, including politeness, humor, and formal versus informal speech', 'children': []}]}, {'dimension_name': 'Non-verbal Social Communication', 'description': 'The ability to use and understand non-verbal cues such as facial expressions, gestures, body language, and spatial awareness in social interactions', 'children': [{'dimension_name': 'Facial Expression Use', 'description': 'The ability to produce and modulate appropriate facial expressions in social interactions', 'children': []}, {'dimension_name': 'Body Language Use', 'description': 'The ability to use appropriate posture, gestures, and physical orientation during social interactions', 'children': []}, {'dimension_name': 'Personal Space Management', 'description': 'The ability to maintain appropriate physical distance and positioning during social interactions', 'children': []}]}]}, {'dimension_name': 'Social Understanding', 'description': "The ability to interpret and comprehend social situations, including understanding others' emotions, intentions, and social norms", 'children': [{'dimension_name': 'Emotional Recognition', 'description': 'The ability to identify and understand emotions in others through facial expressions, vocal tones, and body language', 'children': [{'dimension_name': 'Facial Emotion Recognition', 'description': 'The ability to identify and interpret emotional expressions in faces', 'children': []}, {'dimension_name': 'Vocal Emotion Recognition', 'description': 'The ability to identify and interpret emotional cues in voice tone and speech patterns', 'children': []}, {'dimension_name': 'Body Language Emotion Recognition', 'description': 'The ability to identify and interpret emotional states from body posture and gestures', 'children': []}]}, {'dimension_name': 'Social Context Understanding', 'description': 'The ability to understand and navigate different social situations, including awareness of social norms and appropriate behavior in various contexts', 'children': [{'dimension_name': 'Social Rule Understanding', 'description': 'The ability to comprehend and follow explicit and implicit social rules in different settings', 'children': []}, {'dimension_name': 'Cultural Context Understanding', 'description': 'The ability to recognize and adapt to different cultural norms and expectations in social situations', 'children': []}]}, {'dimension_name': 'Perspective Taking', 'description': "The ability to understand and consider others' thoughts, feelings, and viewpoints, including theory of mind", 'children': [{'dimension_name': 'Cognitive Perspective Taking', 'description': "The ability to understand and predict others' thoughts and beliefs", 'children': []}, {'dimension_name': 'Emotional Perspective Taking', 'description': "The ability to understand and empathize with others' emotional states and experiences", 'children': []}]}]}, {'dimension_name': 'Social Relationships', 'description': 'The ability to form and maintain relationships with others, including peers, family members, and auth ...
# 4
# [{'dimension_name': 'Social Interaction', 'description': 'The ability to engage, respond to, and maintain relationships with others, encompassing both verbal and non-verbal aspects of social behavior and understanding', 'children': [{'dimension_name': 'Social Communication', 'description': 'The ability to send and receive social messages through verbal and non-verbal means, including facial expressions, body language, and tone of voice', 'children': [{'dimension_name': 'Verbal Social Communication', 'description': 'The ability to use and understand spoken language in social contexts, including conversation skills and appropriate verbal responses', 'children': [{'dimension_name': 'Conversational Flow', 'description': 'The ability to maintain back-and-forth dialogue, including turn-taking and topic maintenance in conversations', 'children': [{'dimension_name': 'Turn-Taking Skills', 'description': 'The ability to appropriately alternate between speaking and listening roles in conversation', 'children': []}, {'dimension_name': 'Topic Management', 'description': 'The ability to introduce, maintain, and transition between conversation topics appropriately', 'children': []}]}, {'dimension_name': 'Social Language Use', 'description': 'The ability to use appropriate language for different social situations, including politeness, humor, and formal versus informal speech', 'children': [{'dimension_name': 'Register Adaptation', 'description': 'The ability to adjust language formality and tone according to social context', 'children': []}, {'dimension_name': 'Social Humor', 'description': 'The ability to understand and use humor appropriately in social situations', 'children': []}]}]}, {'dimension_name': 'Non-verbal Social Communication', 'description': 'The ability to use and understand non-verbal cues such as facial expressions, gestures, body language, and spatial awareness in social interactions', 'children': [{'dimension_name': 'Facial Expression Use', 'description': 'The ability to produce and modulate appropriate facial expressions in social interactions', 'children': [{'dimension_name': 'Expression Intensity', 'description': 'The ability to adjust the intensity of facial expressions according to social context', 'children': []}, {'dimension_name': 'Expression Timing', 'description': 'The ability to produce facial expressions at appropriate moments in social interactions', 'children': []}]}, {'dimension_name': 'Body Language Use', 'description': 'The ability to use appropriate posture, gestures, and physical orientation during social interactions', 'children': [{'dimension_name': 'Gesture Appropriateness', 'description': 'The ability to use culturally and socially appropriate gestures', 'children': []}, {'dimension_name': 'Postural Communication', 'description': 'The ability to convey attention and engagement through body posture', 'children': []}]}, {'dimension_name': 'Personal Space Management', 'description': 'The ability to maintain appropriate physical distance and positioning during social interactions', 'children': []}]}]}, {'dimension_name': 'Social Understanding', 'description': "The ability to interpret and comprehend social situations, including understanding others' emotions, intentions, and social norms", 'children': [{'dimension_name': 'Emotional Recognition', 'description': 'The ability to identify and understand emotions in others through facial expressions, vocal tones, and body language', 'children': [{'dimension_name': 'Facial Emotion Recognition', 'description': 'The ability to identify and interpret emotional expressions in faces', 'children': []}, {'dimension_name': 'Vocal Emotion Recognition', 'description': 'The ability to identify and interpret emotional cues in voice tone and speech patterns', 'children': []}, {'dimension_name': 'Body Language Emotion Recognition', 'description': 'The ability to identify and interpret emotional states from body posture and gestures', 'children': []}]}, {'dimension_name': 'S ...
# 5
# ...
# Value Assessment
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Prioritization', 'Value Assessment', 'Personal Significance']
# Personal Significance
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Prioritization', 'Value Assessment', 'Impact Evaluation']
# Impact Evaluation
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Prioritization', 'Resource Allocation']
# Resource Allocation
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Prioritization', 'Resource Allocation', 'Time Management']
# Time Management
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Prioritization', 'Resource Allocation', 'Energy Distribution']
# Energy Distribution
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation']
# Goal Adaptation
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation', 'Flexibility']
# Flexibility
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation', 'Flexibility', 'Goal Adjustment']
# Goal Adjustment
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation', 'Flexibility', 'Alternative Development']
# Alternative Development
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation', 'Reality Testing']
# Reality Testing
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation', 'Reality Testing', 'Situational Assessment']
# Situational Assessment
# ['Motivation and Goal-Directed Behavior', 'Goal Setting', 'Goal Adaptation', 'Reality Testing', 'Capability Evaluation']
# Capability Evaluation
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit']
# Goal Pursuit
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development']
# Strategy Development
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development', 'Action Planning']
# Action Planning
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development', 'Action Planning', 'Task Sequencing']
# Task Sequencing
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development', 'Action Planning', 'Step Specification']
# Step Specification
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development', 'Resource Management']
# Resource Management
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development', 'Resource Management', 'Resource Identification']
# Resource Identification
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Strategy Development', 'Resource Management', 'Resource Utilization']
# Resource Utilization
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence']
# Persistence
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence', 'Effort Sustainment']
# Effort Sustainment
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence', 'Effort Sustainment', 'Energy Management']
# Energy Management
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence', 'Effort Sustainment', 'Focus Maintenance']
# Focus Maintenance
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence', 'Setback Recovery']
# Setback Recovery
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence', 'Setback Recovery', 'Resilience']
# Resilience
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Persistence', 'Setback Recovery', 'Problem Resolution']
# Problem Resolution
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring']
# Progress Monitoring
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring', 'Self-Assessment']
# Self-Assessment
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring', 'Self-Assessment', 'Progress Tracking']
# Progress Tracking
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring', 'Self-Assessment', 'Performance Evaluation']
# Performance Evaluation
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring', 'Adjustment Implementation']
# Adjustment Implementation
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring', 'Adjustment Implementation', 'Strategy Refinement']
# Strategy Refinement
# ['Motivation and Goal-Directed Behavior', 'Goal Pursuit', 'Progress Monitoring', 'Adjustment Implementation', 'Behavior Modification']
# Behavior Modification
# ['Motivation and Goal-Directed Behavior', 'Reward Processing']
# Reward Processing
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation']
# Reward Anticipation
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation', 'Future Reward Visualization']
# Future Reward Visualization
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation', 'Future Reward Visualization', 'Outcome Imagination']
# Outcome Imagination
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation', 'Future Reward Visualization', 'Emotional Forecasting']
# Emotional Forecasting
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation', 'Delayed Gratification']
# Delayed Gratification
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation', 'Delayed Gratification', 'Impulse Control']
# Impulse Control
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Anticipation', 'Delayed Gratification', 'Future Value Assessment']
# Future Value Assessment
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response']
# Reward Response
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response', 'Achievement Satisfaction']
# Achievement Satisfaction
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response', 'Achievement Satisfaction', 'Success Recognition']
# Success Recognition
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response', 'Achievement Satisfaction', 'Emotional Gratification']
# Emotional Gratification
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response', 'Reward Sensitivity']
# Reward Sensitivity
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response', 'Reward Sensitivity', 'Reward Detection']
# Reward Detection
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Response', 'Reward Sensitivity', 'Reward Valuation']
# Reward Valuation
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning']
# Reward Learning
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning', 'Outcome Association']
# Outcome Association
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning', 'Outcome Association', 'Behavior-Reward Connection']
# Behavior-Reward Connection
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning', 'Outcome Association', 'Pattern Recognition']
# Pattern Recognition
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning', 'Behavioral Adaptation']
# Behavioral Adaptation
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning', 'Behavioral Adaptation', 'Strategy Refinement']
# Strategy Refinement
# ['Motivation and Goal-Directed Behavior', 'Reward Processing', 'Reward Learning', 'Behavioral Adaptation', 'Behavior Optimization']
# Behavior Optimization
# ['Self-Concept and Identity']
# Self-Concept and Identity
# ['Self-Concept and Identity', 'Personal Identity']
# Personal Identity
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs']
# Core Values and Beliefs
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Moral Values']
# Moral Values
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Moral Values', 'Ethical Decision-Making']
# Ethical Decision-Making
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Moral Values', 'Moral Consistency']
# Moral Consistency
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Moral Values', 'Value Prioritization']
# Value Prioritization
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Life Philosophy']
# Life Philosophy
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Life Philosophy', 'Existential Understanding']
# Existential Understanding
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Life Philosophy', 'Purpose Recognition']
# Purpose Recognition
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Life Philosophy', 'Worldview Integration']
# Worldview Integration
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Religious/Spiritual Identity']
# Religious/Spiritual Identity
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Religious/Spiritual Identity', 'Spiritual Practice']
# Spiritual Practice
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Religious/Spiritual Identity', 'Faith Integration']
# Faith Integration
# ['Self-Concept and Identity', 'Personal Identity', 'Core Values and Beliefs', 'Religious/Spiritual Identity', 'Transcendent Connection']
# Transcendent Connection
# ['Self-Concept and Identity', 'Personal Identity', 'Personality Expression']
# Personality Expression
# ['Self-Concept and Identity', 'Personal Identity', 'Personality Expression', 'Interpersonal Style']
# Interpersonal Style
# ['Self-Concept and Identity', 'Personal Identity', 'Personality Expression', 'Emotional Expression']
# Emotional Expression
# ['Self-Concept and Identity', 'Personal Identity', 'Personality Expression', 'Coping Style']
# Coping Style
# ['Self-Concept and Identity', 'Personal Identity', 'Personal Narrative']
# Personal Narrative
# ['Self-Concept and Identity', 'Personal Identity', 'Personal Narrative', 'Life Story Integration']
# Life Story Integration
# ['Self-Concept and Identity', 'Personal Identity', 'Personal Narrative', 'Autobiographical Memory']
# Autobiographical Memory
# ['Self-Concept and Identity', 'Personal Identity', 'Personal Narrative', 'Identity Continuity']
# Identity Continuity
# ['Self-Concept and Identity', 'Social Identity']
# Social Identity
# ['Self-Concept and Identity', 'Social Identity', 'Group Membership']
# Group Membership
# ['Self-Concept and Identity', 'Social Identity', 'Group Membership', 'Social Group Affiliation']
# Social Group Affiliation
# ['Self-Concept and Identity', 'Social Identity', 'Group Membership', 'Group Value Alignment']
# Group Value Alignment
# ['Self-Concept and Identity', 'Social Identity', 'Group Membership', 'Intergroup Relations']
# Intergroup Relations
# ['Self-Concept and Identity', 'Social Identity', 'Role Identity']
# Role Identity
# ['Self-Concept and Identity', 'Social Identity', 'Role Identity', 'Role Competence']
# Role Competence
# ['Self-Concept and Identity', 'Social Identity', 'Role Identity', 'Role Integration']
# Role Integration
# ['Self-Concept and Identity', 'Social Identity', 'Role Identity', 'Role Satisfaction']
# Role Satisfaction
# ['Self-Concept and Identity', 'Social Identity', 'Cultural Identity']
# Cultural Identity
# ['Self-Concept and Identity', 'Social Identity', 'Cultural Identity', 'Cultural Knowledge']
# Cultural Knowledge
# ['Self-Concept and Identity', 'Social Identity', 'Cultural Identity', 'Cultural Practice']
# Cultural Practice
# ['Self-Concept and Identity', 'Social Identity', 'Cultural Identity', 'Cultural Adaptation']
# Cultural Adaptation
# ['Self-Concept and Identity', 'Self-Evaluation']
# Self-Evaluation
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Esteem']
# Self-Esteem
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Esteem', 'Global Self-Worth']
# Global Self-Worth
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Esteem', 'Domain-Specific Self-Esteem']
# Domain-Specific Self-Esteem
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Esteem', 'Conditional Self-Worth']
# Conditional Self-Worth
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Efficacy']
# Self-Efficacy
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Efficacy', 'Task-Specific Confidence']
# Task-Specific Confidence
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Efficacy', 'General Competence']
# General Competence
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Efficacy', 'Learning Self-Efficacy']
# Learning Self-Efficacy
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Awareness']
# Self-Awareness
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Awareness', 'Emotional Self-Awareness']
# Emotional Self-Awareness
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Awareness', 'Behavioral Self-Awareness']
# Behavioral Self-Awareness
# ['Self-Concept and Identity', 'Self-Evaluation', 'Self-Awareness', 'Social Impact Awareness']
# Social Impact Awareness
# ['Self-Concept and Identity', 'Body Image and Physical Self']
# Body Image and Physical Self
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Appearance']
# Physical Appearance
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Appearance', 'Appearance Satisfaction']
# Appearance Satisfaction
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Appearance', 'Appearance Investment']
# Appearance Investment
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Appearance', 'Body Size Perception']
# Body Size Perception
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Capabilities']
# Physical Capabilities
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Capabilities', 'Physical Competence']
# Physical Competence
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Capabilities', 'Health Awareness']
# Health Awareness
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Physical Capabilities', 'Physical Limitation Acceptance']
# Physical Limitation Acceptance
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Body Acceptance']
# Body Acceptance
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Body Acceptance', 'Body Appreciation']
# Body Appreciation
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Body Acceptance', 'Body Functionality']
# Body Functionality
# ['Self-Concept and Identity', 'Body Image and Physical Self', 'Body Acceptance', 'Body-Mind Integration']
# Body-Mind Integration
# ['Self-Concept and Identity', 'Temporal Self-Concept']
# Temporal Self-Concept
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Past Self']
# Past Self
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Past Self', 'Life Transitions']
# Life Transitions
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Past Self', 'Personal Growth']
# Personal Growth
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Past Self', 'Historical Continuity']
# Historical Continuity
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Present Self']
# Present Self
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Present Self', 'Current Circumstances']
# Current Circumstances
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Present Self', 'Present-Moment Awareness']
# Present-Moment Awareness
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Present Self', 'Current Life Satisfaction']
# Current Life Satisfaction
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Future Self']
# Future Self
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Future Self', 'Personal Goals']
# Personal Goals
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Future Self', 'Identity Development']
# Identity Development
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Future Self', 'Future Adaptability']
# Future Adaptability
# ['Self-Concept and Identity', 'Temporal Self-Concept', 'Future Self', 'Future Adaptability', <NA>, <NA>, 'Ability to navigate between different cultural contexts and expectations.']

# %%
result_df
# Out:
#                        level_1               level_2               level_3  \
# 0           Cognitive Function
# 1           Cognitive Function                Memory
# 2           Cognitive Function                Memory        Working Memory
# 3           Cognitive Function                Memory        Working Memory
# 4           Cognitive Function                Memory        Working Memory
# ..                         ...                   ...                   ...
# 655  Self-Concept and Identity  Identity Development   Identity Commitment
# 656  Self-Concept and Identity  Identity Development  Identity Integration
# 657  Self-Concept and Identity  Identity Development  Identity Integration
# 658  Self-Concept and Identity  Identity Development  Identity Integration
# 659  Self-Concept and Identity  Identity Development  Identity Integration
#
#                    level_4            level_5  \
# 0
# 1
# 2
# 3    Verbal Working Memory
# 4    Verbal Working Memory  Phonological Loop
# ..                     ...                ...
# 655        Goal Commitment
# 656
# 657     Identity Coherence
# 658   Identity Flexibility
# 659  Identity Authenticity
#
#                                            description
# 0    Core mental abilities and processes that enabl...
# 1    The ability to encode, store, and retrieve inf...
# 2    The ability to temporarily hold and manipulate...
# 3    The ability to temporarily hold and manipulate...
# 4    The component responsible for temporarily stor...
# ..                                                 ...
# 655  Personal memories and recollections that contr...
# 656  Significant changes and turning points that ha...
# 657  Goals, dreams, and plans that contribute to on...
# 658  How individuals understand and express themsel...
# 659  The sense of belonging and connection to cultu...
#
# [660 rows x 6 columns]

# %%
i = 1
region = 'us-east-1'
with open('RDoC_domains.json') as f:
    input = json.load(f)
with open('RDoC_prompt.txt') as f:
    prompt = f.read()
client = anthropic.AnthropicBedrock(
        aws_access_key = os.environ.get('AWS_ACCESS_KEY_ID'),
        aws_secret_key = os.environ.get('AWS_SECRET_ACCESS_KEY'),
        aws_region=region,
    )

message = client.messages.create(
        model='anthropic.claude-3-5-sonnet-20240620-v1:0',
        max_tokens=8000,
        messages=[
            {'role':'user',
            'content':eval(prompt)},
            ]
        )
iterations_completed = i 
print(message)
# Out:
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/maya.roberts/code/aimless/aimless-env/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:anthropic._base_client:Request options: {'method': 'post', 'url': '/model/anthropic.claude-3-5-sonnet-20240620-v1:0/invoke', 'timeout': 600, 'files': None, 'json_data': {'max_tokens': 8000, 'messages': [{'role': 'user', 'content': 'We are creating a hierarchical model of neuropsychological concepts. This model will be ultimately used as rating scales to assess function in specific dimensions of neuropsychology. \nEach dimension of functioning should be neutral and applicable to the general population, not only disorders. Extreme presentations of a dimension may be related to a cognitive or psychological disorder. \nEach dimension should also relate to an evidence-based scientific concept or construct for the field of neuropsychology and child development.\nEach dimension must have a "parent" dimension (unless they are "root" dimensions) and zero, one or more "child" dimensions, illustrating the notion of sub-components or special cases of dimensions.\n\nThe “root” dimensions, or highest level psychological domains, should be the following:\n    1. Negative Valence Systems: primarily responsible for responses to aversive situations or context, such as fear, anxiety, and loss.\n    2. Positive Valence Systems: primarily responsible for responses to positive motivational situations or contexts, such as reward seeking, consummatory behavior, and reward/habit learning.\n    3. Cognitive Systems: responsible for various cognitive processes.\n    4. Systems for Social Processes: mediate responses in interpersonal settings of various types, including perception and interpretation of others’ actions.\n    5. Arousal/Regulatory Systems: responsible for generating activation of neural systems as appropriate for various contexts and providing appropriate homeostatic regulation of such systems as energy balance and sleep.\n    6. Sensorimotor Systems: primarily responsible for the control and execution of motor behaviors, and their refinement during learning and development.\n\nInclude the following attributes for each dimension:\n    - "title" is the name of the dimension, related to an established concept or construct.\n    - "description" is a brief description of the dimension.\n    - "children" is a list of dimensions, each following the same format, that fall under the umbrella of this higher level category.\n\nYour job is to subdivide the dimensions of this tree, one level at a time. I will give you the current hierarchical model, and you add children dimensions as relevant. \n\nWe will continue to iterate and split these dimensions until either (a) you determine we have reached the lowest measurable dimensions of neuropsychology, or (b) we complete 10 iterations of this prompt. When creating your subdivisions, keep in mind this is iteration number 1.\n\nIf a dimension does not have any relevant subcategories, and represents a single measurable dimension, return it as is, keeping the description identical, and leave the "children" attribute empty. Do not add unnecessary dimensions or sublevels.\n\nDo not remove or edit any dimension names or descriptions. You are only responsible for adding new dimensions. Do not make the dimensions overly specific, especially on the first and second iterations. Increase the specificity of the dimensions as you add more layers to the model. Only add one additional level to the model at a time. Again, keep in mind that this is iteration number 1.\n\nHere is the current model: [{\'dimension_name\': \'Negative Valence Systems\', \'description\': \'Negative Valence Systems are primarily responsible for responses to aversive situations or context, such as fear, anxiety, and loss.\', \'children\': []}, {\'dimension_name\': \'Positive Valence Systems\', \'description\': \'Positive Valence Systems are primarily responsible for responses to positive motivational situations or contexts, such as reward seeking and consummatory behavior.\', \'children\': []}, {\'dimension_name\': \'Cognitive Systems\', \' ...
# DEBUG:botocore.auth:Calculating signature using v4 auth.
# DEBUG:botocore.auth:CanonicalRequest:
# POST
# /model/anthropic.claude-3-5-sonnet-20240620-v1%3A0/invoke
#
# accept:application/json
# accept-encoding:gzip, deflate
# content-length:4761
# content-type:application/json
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20241022T210146Z
# x-stainless-arch:arm64
# x-stainless-lang:python
# x-stainless-os:MacOS
# x-stainless-package-version:0.37.0
# x-stainless-retry-count:0
# x-stainless-runtime:CPython
# x-stainless-runtime-version:3.11.2
#
# accept;accept-encoding;content-length;content-type;host;x-amz-date;x-stainless-arch;x-stainless-lang;x-stainless-os;x-stainless-package-version;x-stainless-retry-count;x-stainless-runtime;x-stainless-runtime-version
# 255eaab912187e37ebc1895166c348c2cd827e14ff992f7fb4e3048ef2b9ee1d
# DEBUG:botocore.auth:StringToSign:
# AWS4-HMAC-SHA256
# 20241022T210146Z
# 20241022/us-east-1/bedrock/aws4_request
# 957387e18311c0e968aa84fccd88b80c457d96d7b907ef090f4bbdc68585b07e
# DEBUG:botocore.auth:Signature:
# c171bfe29542d26cac9658ebfec981a273a4832d5256373d60512d9660b3b7bd
# DEBUG:anthropic._base_client:Sending HTTP Request: POST https://bedrock-runtime.us-east-1.amazonaws.com/model/anthropic.claude-3-5-sonnet-20240620-v1:0/invoke
# DEBUG:httpcore.connection:connect_tcp.started host='bedrock-runtime.us-east-1.amazonaws.com' port=443 local_address=None timeout=600 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x138402610>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x111648e60> server_hostname='bedrock-runtime.us-east-1.amazonaws.com' timeout=600
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x110048090>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 22 Oct 2024 21:02:28 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'7862'), (b'Connection', b'keep-alive'), (b'x-amzn-RequestId', b'c5ec4e25-657c-4528-9af4-935c60a1b033'), (b'X-Amzn-Bedrock-Invocation-Latency', b'41404'), (b'X-Amzn-Bedrock-Output-Token-Count', b'1658'), (b'X-Amzn-Bedrock-Input-Token-Count', b'984')])
# INFO:httpx:HTTP Request: POST https://bedrock-runtime.us-east-1.amazonaws.com/model/anthropic.claude-3-5-sonnet-20240620-v1:0/invoke "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:anthropic._base_client:HTTP Response: POST https://bedrock-runtime.us-east-1.amazonaws.com/model/anthropic.claude-3-5-sonnet-20240620-v1:0/invoke "200 OK" Headers({'date': 'Tue, 22 Oct 2024 21:02:28 GMT', 'content-type': 'application/json', 'content-length': '7862', 'connection': 'keep-alive', 'x-amzn-requestid': 'c5ec4e25-657c-4528-9af4-935c60a1b033', 'x-amzn-bedrock-invocation-latency': '41404', 'x-amzn-bedrock-output-token-count': '1658', 'x-amzn-bedrock-input-token-count': '984'})
# DEBUG:anthropic._base_client:request_id: None
# Message(id='msg_bdrk_01SY5QJcGik5ZyswR4zsNVx5', content=[TextBlock(text='Here\'s the updated model with one level of subdivision added to each root dimension:\n\n[\n  {\n    "dimension_name": "Negative Valence Systems",\n    "description": "Negative Valence Systems are primarily responsible for responses to aversive situations or context, such as fear, anxiety, and loss.",\n    "children": [\n      {\n        "dimension_name": "Acute Threat (Fear)",\n        "description": "Activation of the fear system in response to present or imminent threat.",\n        "children": []\n      },\n      {\n        "dimension_name": "Potential Threat (Anxiety)",\n        "description": "Activation of a system of responses to potential harm or threat.",\n        "children": []\n      },\n      {\n        "dimension_name": "Sustained Threat",\n        "description": "An aversive emotional state caused by prolonged (i.e., weeks to months) exposure to internal and/or external condition(s), state(s), or stimuli that are adaptive to escape or avoid.",\n        "children": []\n      },\n      {\n        "dimension_name": "Loss",\n        "description": "A state of deprivation of a motivationally significant con-specific, object, or situation.",\n        "children": []\n      }\n    ]\n  },\n  {\n    "dimension_name": "Positive Valence Systems",\n    "description": "Positive Valence Systems are primarily responsible for responses to positive motivational situations or contexts, such as reward seeking and consummatory behavior.",\n    "children": [\n      {\n        "dimension_name": "Reward Responsiveness",\n        "description": "Processes by which organisms respond to occurrences of positive reinforcers, and the learning processes underlying such responses.",\n        "children": []\n      },\n      {\n        "dimension_name": "Reward Learning",\n        "description": "A process by which organisms acquire information about stimuli, actions, and contexts that predict positive outcomes, and by which behavior is modified when a novel reward occurs or outcomes are better than expected.",\n        "children": []\n      },\n      {\n        "dimension_name": "Reward Valuation",\n        "description": "Processes by which the probability and benefits of a prospective outcome are computed and calibrated by reference to external information, social context, and/or prior experience.",\n        "children": []\n      }\n    ]\n  },\n  {\n    "dimension_name": "Cognitive Systems",\n    "description": "Cognitive Systems are responsible for various cognitive processes.",\n    "children": [\n      {\n        "dimension_name": "Attention",\n        "description": "Regulation of capacity-limited systems such as awareness, higher-order perception, and other operations through the selection and maintenance of target information.",\n        "children": []\n      },\n      {\n        "dimension_name": "Perception",\n        "description": "The process(es) that perform computations on sensory data to construct and transform representations of the external environment.",\n        "children": []\n      },\n      {\n        "dimension_name": "Memory",\n        "description": "The acquisition, encoding, storage, and retrieval of information.",\n        "children": []\n      },\n      {\n        "dimension_name": "Language",\n        "description": "A system of shared symbolic representations of the world, the self and abstract concepts that supports thought and communication.",\n        "children": []\n      },\n      {\n        "dimension_name": "Cognitive Control",\n        "description": "A system that modulates the operation of other cognitive and emotional systems in the service of goal-directed behavior.",\n        "children": []\n      }\n    ]\n  },\n  {\n    "dimension_name": "Social Processes Systems",\n    "description": "Social Processes mediate responses in interpersonal settings of various types, including perception and interpretation of others\' actions",\n ...

# %%
with open('RDoC_domains.json') as f:
    input = json.load(f)
with open('RDoC_prompt.txt') as f:
    prompt = f.read()


for i in range(i, 10):
    client = anthropic.AnthropicBedrock(
            aws_access_key = os.environ.get('AWS_ACCESS_KEY_ID'),
            aws_secret_key = os.environ.get('AWS_SECRET_ACCESS_KEY'),
            aws_region='us-east-1',
        )

    message = client.messages.create(
        model='anthropic.claude-3-5-sonnet-20240620-v1:0',
        max_tokens=8000,
        messages=[
            {'role':'user',
            'content':eval(prompt)},
            
            ]
        )

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x105dc9bd0>>

# %%
with open('RDoC_prompt.txt') as f:
    prompt = f.read()
with open('RDoC_domains.json') as f:
    input = json.load(f)
i = 4
print(eval(prompt))
# Out:
# We are creating a hierarchical model of neuropsychological concepts. This model will be ultimately used as rating scales to assess function in specific dimensions of neuropsychology.
# Each dimension of functioning should be neutral and applicable to the general population, not only disorders. Extreme presentations of a dimension may be related to a cognitive or psychological disorder.
# Each dimension should also relate to an evidence-based scientific concept or construct for the field of neuropsychology and child development.
# Each dimension must have a "parent" dimension (unless they are "root" dimensions) and zero, one or more "child" dimensions, illustrating the notion of sub-components or special cases of dimensions.
#
# The “root” dimensions, or highest level psychological domains, should be the following:
#     1. Negative Valence Systems: primarily responsible for responses to aversive situations or context, such as fear, anxiety, and loss.
#     2. Positive Valence Systems: primarily responsible for responses to positive motivational situations or contexts, such as reward seeking, consummatory behavior, and reward/habit learning.
#     3. Cognitive Systems: responsible for various cognitive processes.
#     4. Systems for Social Processes: mediate responses in interpersonal settings of various types, including perception and interpretation of others’ actions.
#     5. Arousal/Regulatory Systems: responsible for generating activation of neural systems as appropriate for various contexts and providing appropriate homeostatic regulation of such systems as energy balance and sleep.
#     6. Sensorimotor Systems: primarily responsible for the control and execution of motor behaviors, and their refinement during learning and development.
#
# Include the following attributes for each dimension:
#     - "title" is the name of the dimension, related to an established concept or construct.
#     - "description" is a brief description of the dimension.
#     - "children" is a list of dimensions, each following the same format, that fall under the umbrella of this higher level category.
#
# Your job is to subdivide the dimensions of this tree, one level at a time. I will give you the current hierarchical model, and you add children dimensions as relevant.
#
# We will continue to iterate and split these dimensions until either (a) you determine we have reached the lowest measurable dimensions of neuropsychology, or (b) we complete 10 iterations of this prompt. When creating your subdivisions, keep in mind this is iteration number 4.
#
# If a dimension does not have any relevant subcategories, and represents a single measurable dimension, return it as is, keeping the description identical, and leave the "children" attribute empty. Do not add unnecessary dimensions or sublevels.
#
# Do not remove or edit any dimension names or descriptions. You are only responsible for adding new dimensions. Do not make the dimensions overly specific, especially on the first and second iterations. Increase the specificity of the dimensions as you add more layers to the model. Only add one additional level to the model at a time. Again, keep in mind that this is iteration number 4.
#
# Here is the current model: [{'dimension_name': 'Negative Valence Systems', 'description': 'Negative Valence Systems are primarily responsible for responses to aversive situations or context, such as fear, anxiety, and loss.', 'children': []}, {'dimension_name': 'Positive Valence Systems', 'description': 'Positive Valence Systems are primarily responsible for responses to positive motivational situations or contexts, such as reward seeking and consummatory behavior.', 'children': []}, {'dimension_name': 'Cognitive Systems', 'description': 'Cognitive Systems are responsible for various cognitive processes.', 'children': []}, {'dimension_name': 'Social Processes Systems', 'description': 'Social Processes mediate responses in interpersonal settings of various types, including perception and interpretation of others’ actions', 'children': []}, {'dimension_name': 'Arousal/Regulatory Systems', 'description': 'Arousal/Regulatory Systems are responsible for generating activation of neural systems as appropriate for various contexts and providing appropriate homeostatic regulation of such systems as energy balance and sleep.', 'children': []}, {'dimension_name': 'Sensorimotor Systems', 'description': 'Sensorimotor Systems are primarily responsible for the control and execution of motor behaviors, and their refinement during learning and development.', 'children': []}].
#
# Return the updated model.

# %%
result_df.to_csv('RDoC_hierarchy.csv', index=False)

# %%
pd.unique(result_df['level_8'])
# Out:
# array([''], dtype=object)

# %%
import plotly.express as px
fig = px.treemap(
    names = dimensions,
    parents = parents,
)
fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25), width=2000, height=2000)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import plotly.express as px
#       2 fig = px.treemap(
# ----> 3     names = dimensions,
#       4     parents = parents,
#       5 )
#       6 fig.update_traces(root_color="lightgrey")
#       7 fig.update_layout(margin = dict(t=50, l=25, r=25, b=25), width=2000, height=2000)
#
# NameError: name 'dimensions' is not defined

# %%
fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      color = "blue"
    ),
    link = dict(
      source = dimensions, # indices correspond to labels, eg A1, A2, A1, B1, ...
      target = parents,
      value = [1] * len(parents) ,
  ))])

fig.update_layout(width = 2000, height = 1000)
fig.show()
